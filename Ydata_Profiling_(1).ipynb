# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheerajm00009/YData-Profiling/blob/main/Ydata_Profiling_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling[notebook]

# %%
# !pip install pdfkit

# %%
# !apt-get update
# !apt-get install -y wkhtmltopdf
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,607 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,701 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,863 kB]
# ...

# %%
# !which wkhtmltopdf
# Out:
# /usr/bin/wkhtmltopdf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from ydata_profiling import ProfileReport

# %%
from ydata_profiling import ProfileReport
import pandas as pd
import pdfkit

# %%
df = pd.read_csv('AirPassengers.csv')

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.columns
# Out:
# Index(['Month', '#Passengers'], dtype='object')

# %%
df.columns = ['Date', 'Passengers']

# %%
df['Month'] = (df['Date'].str.split('-').str[0]).astype(int)
df['Year'] = (df['Date'].str.split('-').str[1]).astype(int)

# %%
df.head()
# Out:
#       Date  Passengers  Month  Year
# 0  1949-01         112   1949     1
# 1  1949-02         118   1949     2
# 2  1949-03         132   1949     3
# 3  1949-04         129   1949     4
# 4  1949-05         121   1949     5

# %%
df = df[['Year', 'Month', 'Passengers']]

# %%
df.head()
# Out:
#    Year  Month  Passengers
# 0     1   1949         112
# 1     2   1949         118
# 2     3   1949         132
# 3     4   1949         129
# 4     5   1949         121

# %%
profile = ProfileReport(df, title="AirPassengers Dataset Profiling", explorative=True)

# %%
html_file = "AirPassengers Dataset Profiling.html"
profile.to_file(html_file)

# Convert the HTML file to a PDF
pdf_file = "AirPassengers Dataset Profiling.pdf"
config = pdfkit.configuration(wkhtmltopdf='/usr/bin/wkhtmltopdf') # Replace with the output from !which wkhtmltopdf
pdfkit.from_file(html_file, pdf_file, configuration=config)
print(f"PDF report has been saved as {pdf_file}")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# PDF report has been saved as AirPassengers Dataset Profiling.pdf

# %%
df1 = pd.read_csv('Iris_Dataset.csv')

# %%
profile1 = ProfileReport(df1, title="Iris Dataset Profiling", explorative=True)

# %%
html_file = "Iris Dataset Profiling.html"
profile1.to_file(html_file)

# Convert the HTML file to a PDF
pdf_file = "Iris Dataset Profiling.pdf"
pdfkit_config = pdfkit.configuration(wkhtmltopdf='/usr/bin/wkhtmltopdf')
pdfkit.from_file(html_file, pdf_file, configuration=pdfkit_config)

print(f"PDF report has been saved as {pdf_file}")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# PDF report has been saved as Iris Dataset Profiling.pdf
